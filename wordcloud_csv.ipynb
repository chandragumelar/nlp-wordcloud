# %%
import os
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# get cwd
cwd = os.getcwd()
cwd
# Out:
# '/Users/desiirani/Documents/py-playground'

# %%
ls
# Out:
# SDFB_people.csv       sherlock.txt          wordcloud_txt.ipynb
# Untitled.ipynb        train_author_nlp.csv
# bolt_hometest.csv     wordcloud.ipynb

# %%
# construct the path
file_path = os.path.join(cwd, 'SDFB_people.csv')

# read the file
df = pd.read_csv(file_path)
df.head()
# Out:
#    SDFB Person ID  ODNB ID      Display Name Prefix First Name Last Name  \
# 0        10005815  13002.0     James Hepburn    NaN      James   Hepburn
# 1        10007183  16127.0     John Laurence    NaN       John  Laurence
# 2        10005953  13283.0       Joseph Hill    NaN     Joseph      Hill
# 3        10011043  25406.0   Andrew Shilling    NaN     Andrew  Shilling
# 4        10004471   9910.0  Sir John Forster    Sir       John   Forster
#
#   Suffix Title                                   All Search Names Gender  \
# 0    NaN   NaN                James Hepburn, James, James Hepburn   male
# 1    NaN   NaN                 John Laurence, John, John Laurence   male
# 2    NaN   NaN                   Joseph Hill, Joseph, Joseph Hill   male
# 3    NaN   NaN           Andrew Shilling, Andrew, Andrew Shilling   male
# 4    NaN   NaN  John Forster, Sir John, Sir John Forster, Sir ...   male
#
#                    Historical Significance Birth Year Type Extant Birth Year  \
# 0                              orientalist              IN              1573
# 1                      writer on gardening              IN              1668
# 2                   nonconformist minister              IN              1625
# 3  naval officer in the East India Company              AF              1511
# 4                administrator and soldier              IN              1515
#
#   Alternate Birth Year Death Year Type Extant Death Year Alternate Death Year  \
# 0                 1573           AF/IN              1623                 1623
# 1                 1668              IN              1732                 1732
# 2                 1625              IN              1707                 1707
# 3                  NaN              IN              1621                 1621
# 4                 1515              IN              1602                 1602
#
#   Group List
# 0         []
# 1         []
# 2         []
# 3         []
# 4         []

# %%
# get all the text that is not null
histsign = df['Historical Significance'][-pd.isnull(df['Historical Significance'])]
text = ' '.join(histsign)

# making wordcloud
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
